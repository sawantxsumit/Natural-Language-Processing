# %% [markdown]
# # Parts of speech

# %%
from nltk import pos_tag

# %% [markdown]
# CC – Coordinating conjunction
#
# CD – Cardinal number
#
# DT – Determiner
#
# EX – Existential there
#
# FW – Foreign word
#
# IN – Preposition / subordinating conjunction
#
# JJ – Adjective
#
# JJR – Adjective, comparative
#
# JJS – Adjective, superlative
#
# LS – List item marker
#
# MD – Modal
#
# NN – Noun, singular
#
# NNS – Noun, plural
#
# NNP – Proper noun, singular
# NNPS – Proper noun, plural
#
# PDT – Predeterminer
#
# POS – Possessive ending (’s)
#
# PRP – Personal pronoun
#
# PRP$ – Possessive pronoun
#
# RB – Adverb
#
# RBR – Adverb, comparative
#
# RBS – Adverb, superlative
#
# RP – Particle
#
# SYM – Symbol
#
# TO – "to"
#
# UH – Interjection
#
# VB – Verb, base form
#
# VBD – Verb, past tense
#
# VBG – Verb, gerund/present participle
#
# VBN – Verb, past participle
#
# VBP – Verb, non-3rd person singular present
# VBZ – Verb, 3rd person singular present
#
# WDT – Wh-determiner
#
# WP – Wh-pronoun
#
# WP$ – Possessive wh-pronoun
#
# WRB – Wh-adverb

# %%
# speech by adbul kalam
speech= '''Honourable Members, this is true for the whole world. When we need peace in the world, we need order in the nation. We need harmony in the home. Whether in Europe, India, or any part of the world, the origin is righteousness in the heart. How do we instil righteousness in the heart of every citizen of the world? This is my area of specialisation and I would like to talk to you about it.

First, I wish to discuss the evolution of an enlightened society. With this spirit of righteousness in the heart, I would like to present to this important gathering a methodology for developing a happy, prosperous and peaceful society in our world, which I call “Evolution of Enlightened Society”. I have shared these thoughts with many intellectuals in national and international circles. We need to create an enlightened society with three components:
1.education with a value system: Education must be designed so that righteousness in the heart is developed in young minds. That should be the mission of education. The prime learning environment is five to seventeen years of age. That reminds me of what an ancient Greek teacher said a few thousand years ago: “Give me a child for seven years; afterwards, let God or the devil take the child. They cannot change my child.” This shows the power of great teachers and what they can inculcate in young minds…

2.Religion transforming into spirituality: Religion can focus on a spiritual force that promotes good human life and societal welfare. I witnessed this when Dr. Vikram Sarabhai sought land for a space centre and was shown exceptional understanding by a religious leader, demonstrating that science and spirituality can converge for human prosperity…

3.Economic development for societal transformation:Economic progress must reach every segment of society—rural, urban, rich, or poor—bringing quality of life through nutrition, healthcare, education, and infrastructure, integrated with civilizational values… This leads to a comprehensive development of the nation and smiles on a billion faces.
'''

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import nltk

# %%
porter= PorterStemmer()

# %%
sentences=nltk.sent_tokenize(speech)

# %%
sentences
# Out:
# ['Honourable Members, this is true for the whole world.',
#  'When we need peace in the world, we need order in the nation.',
#  'We need harmony in the home.',
#  'Whether in Europe, India, or any part of the world, the origin is righteousness in the heart.',
#  'How do we instil righteousness in the heart of every citizen of the world?',
#  'This is my area of specialisation and I would like to talk to you about it.',
#  'First, I wish to discuss the evolution of an enlightened society.',
#  'With this spirit of righteousness in the heart, I would like to present to this important gathering a methodology for developing a happy, prosperous and peaceful society in our world, which I call “Evolution of Enlightened Society”.',
#  'I have shared these thoughts with many intellectuals in national and international circles.',
#  'We need to create an enlightened society with three components:\n1.education with a value system: Education must be designed so that righteousness in the heart is developed in young minds.',
#  'That should be the mission of education.',
#  'The prime learning environment is five to seventeen years of age.',
#  'That reminds me of what an ancient Greek teacher said a few thousand years ago: “Give me a child for seven years; afterwards, let God or the devil take the child.',
#  'They cannot change my child.” This shows the power of great teachers and what they can inculcate in young minds…\n\n2.Religion transforming into spirituality: Religion can focus on a spiritual force that promotes good human life and societal welfare.',
#  'I witnessed this when Dr. Vikram Sarabhai sought land for a space centre and was shown exceptional understanding by a religious leader, demonstrating that science and spirituality can converge for human prosperity…\n\n3.Economic development for societal transformation:Economic progress must reach every segment of society—rural, urban, rich, or poor—bringing quality of life through nutrition, healthcare, education, and infrastructure, integrated with civilizational values… This leads to a comprehensive development of the nation and smiles on a billion faces.']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\sawan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
# we will find the pos tag 
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[word for word in words if word not in set(stopwords.words('english'))]
    # sentences[i]= " ".join(words) # converting all the words into sentences again after removing stopwords
    pos_tag=nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('Honourable', 'JJ'), ('Members', 'NNS'), (',', ','), ('true', 'JJ'), ('whole', 'JJ'), ('world', 'NN'), ('.', '.')]
# [('When', 'WRB'), ('need', 'MD'), ('peace', 'VB'), ('world', 'NN'), (',', ','), ('need', 'VBP'), ('order', 'NN'), ('nation', 'NN'), ('.', '.')]
# [('We', 'PRP'), ('need', 'VBP'), ('harmony', 'JJ'), ('home', 'NN'), ('.', '.')]
# [('Whether', 'NNP'), ('Europe', 'NNP'), (',', ','), ('India', 'NNP'), (',', ','), ('part', 'NN'), ('world', 'NN'), (',', ','), ('origin', 'VBP'), ('righteousness', 'JJ'), ('heart', 'NN'), ('.', '.')]
# [('How', 'WRB'), ('instil', 'JJ'), ('righteousness', 'JJ'), ('heart', 'NN'), ('every', 'DT'), ('citizen', 'NN'), ('world', 'NN'), ('?', '.')]
# [('This', 'DT'), ('area', 'NN'), ('specialisation', 'NN'), ('I', 'PRP'), ('would', 'MD'), ('like', 'VB'), ('talk', 'NN'), ('.', '.')]
# [('First', 'RB'), (',', ','), ('I', 'PRP'), ('wish', 'VBP'), ('discuss', 'JJ'), ('evolution', 'NN'), ('enlightened', 'VBD'), ('society', 'NN'), ('.', '.')]
# [('With', 'IN'), ('spirit', 'JJ'), ('righteousness', 'JJ'), ('heart', 'NN'), (',', ','), ('I', 'PRP'), ('would', 'MD'), ('like', 'VB'), ('present', 'JJ'), ('important', 'JJ'), ('gathering', 'NN'), ('methodology', 'NN'), ('developing', 'VBG'), ('happy', 'JJ'), (',', ','), ('prosperous', 'JJ'), ('peaceful', 'JJ'), ('society', 'NN'), ('world', 'NN'), (',', ','), ('I', 'PRP'), ('call', 'VBP'), ('“', 'JJ'), ('Evolution', 'NNP'), ('Enlightened', 'VBD'), ('Society', 'NNP'), ('”', 'NNP'), ('.', '.')]
# [('I', 'PRP'), ('shared', 'VBD'), ('thoughts', 'NNS'), ('many', 'JJ'), ('intellectuals', 'NNS'), ('national', 'JJ'), ('international', 'JJ'), ('circles', 'NNS'), ('.', '.')]
# [('We', 'PRP'), ('need', 'VBP'), ('create', 'JJ'), ('enlightened', 'VBN'), ('society', 'NN'), ('three', 'CD'), ('components', 'NNS'), (':', ':'), ('1.education', 'CD'), ('value', 'NN'), ('system', 'NN'), (':', ':'), ('Education', 'NN'), ('must', 'MD'), ('designed', 'VBN'), ('righteousness', 'VB'), ('heart', 'NN'), ('developed', 'VBN'), ('young', 'JJ'), ('minds', 'NNS'), ('.', '.')]
# [('That', 'DT'), ('mission', 'NN'), ('education', 'NN'), ('.', '.')]
# [('The', 'DT'), ('prime', 'JJ'), ('learning', 'NN'), ('environment', 'NN'), ('five', 'CD'), ('seventeen', 'JJ'), ('years', 'NNS'), ('age', 'NN'), ('.', '.')]
# [('That', 'DT'), ('reminds', 'VBZ'), ('ancient', 'JJ'), ('Greek', 'NNP'), ('teacher', 'NN'), ('said', 'VBD'), ('thousand', 'CD'), ('years', 'NNS'), ('ago', 'RB'), (':', ':'), ('“', 'NN'), ('Give', 'NNP'), ('child', 'NN'), ('seven', 'CD'), ('years', 'NNS'), (';', ':'), ('afterwards', 'NNS'), (',', ','), ('let', 'VB'), ('God', 'NNP'), ('devil', 'VB'), ('take', 'VB'), ('child', 'NN'), ('.', '.')]
# [('They', 'PRP'), ('change', 'VBP'), ('child.', 'JJ'), ('”', 'NN'), ('This', 'DT'), ('shows', 'VBZ'), ('power', 'NN'), ('great', 'JJ'), ('teachers', 'NNS'), ('inculcate', 'VBP'), ('young', 'JJ'), ('minds…', 'VBP'), ('2.Religion', 'CD'), ('transforming', 'VBG'), ('spirituality', 'NN'), (':', ':'), ('Religion', 'NN'), ('focus', 'VBP'), ('spiritual', 'JJ'), ('force', 'NN'), ('promotes', 'NNS'), ('good', 'JJ'), ('human', 'JJ'), ('life', 'NN'), ('societal', 'NN'), ('welfare', 'NN'), ('.', '.')]
# [('I', 'PRP'), ('witnessed', 'VBD'), ('Dr.', 'NNP'), ('Vikram', 'NNP'), ('Sarabhai', 'NNP'), ('sought', 'VBD'), ('land', 'NN'), ('space', 'NN'), ('centre', 'VBP'), ('shown', 'VBN'), ('exceptional', 'JJ'), ('understanding', 'NN'), ('religious', 'JJ'), ('leader', 'NN'), (',', ','), ('demonstrating', 'VBG'), ('science', 'NN'), ('spirituality', 'NN'), ('converge', 'NN'), ('human', 'JJ'), ('prosperity…', 'VBZ'), ('3.Economic', 'CD'), ('development', 'NN'), ('societal', 'JJ'), ('transformation', 'NN'), (':', ':'), ('Economic', 'JJ'), ('progress', 'NN'), ('must', 'MD'), ('reach', 'VB'), ('every', 'DT'), ('segment', 'NN'), ('society—rural', 'NN'), (',', ','), ('urban', 'JJ'), (',', ','), ('rich', 'JJ'), (',', ','), ('poor—bringing', 'VBG'), ('quality', 'NN'), ('life', 'NN'), ('nutrition', 'NN'), (',', ','), ('healthcare', 'NN'), (',', ','), ('education', 'NN'), (',', ','), ('infrastructure', 'NN'), (',', ','), ('integrated', 'VBN'), ('civilizational', 'JJ'), ('values…', 'NN'), ('This', 'DT'), ('leads', 'VBZ'), ('comprehensive', 'JJ'), ('development', 'NN'), ('nation', 'NN'), ('smiles', 'VBZ'), ('billion', 'CD'), ('faces', 'VBZ'), ('.', '.')]

# %%
s=["Taj mahal is a beautiful monument"]
nltk.pos_tag(nltk.word_tokenize(s))
# Out:
# [('Taj', 'NNP'),
#  ('mahal', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('beautiful', 'JJ'),
#  ('monument', 'NN')]

# %%
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\sawan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\universal_tagset.zip.
# True

# %%
s=[
    nltk.word_tokenize("Taj mahal is a beautiful monument"),
    nltk.word_tokenize("taj mahal is situated in agra")]
nltk.pos_tag_sents((s), tagset='universal')
# Out:
# [[('Taj', 'NOUN'),
#   ('mahal', 'NOUN'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('beautiful', 'ADJ'),
#   ('monument', 'NOUN')],
#  [('taj', 'NOUN'),
#   ('mahal', 'NOUN'),
#   ('is', 'VERB'),
#   ('situated', 'VERB'),
#   ('in', 'ADP'),
#   ('agra', 'NOUN')]]
