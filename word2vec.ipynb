# %%
import scipy

# %%
import gensim

# %%
import gensim.downloader as api

# %%
from gensim.models import KeyedVectors

# Load pre-trained Word2Vec model (takes some time, but no re-download)
wv = KeyedVectors.load_word2vec_format(
    "E:\MLnotebook\models\GoogleNews-vectors-negative300.bin",
    binary=True
)

# %%
vec_king=wv['king']

# %%
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
vec_king.shape
# Out:
# (300,)

# %%
wv.most_similar('cricket', restrict_vocab=500000, topn=10)
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
wv.most_similar('machine', restrict_vocab=500000, topn=10)
# Out:
# [('machines', 0.7677488327026367),
#  ('machinery', 0.5260838866233826),
#  ('Machine', 0.5063987374305725),
#  ('grinder', 0.4667676091194153),
#  ('CNC_machines', 0.4572822153568268),
#  ('Machines', 0.45715779066085815),
#  ('apparatus', 0.45392513275146484),
#  ('lathes', 0.4519963562488556),
#  ('computerized', 0.44946369528770447),
#  ('tabulator', 0.44933807849884033)]

# %%
wv.most_similar('youtube', restrict_vocab=500000, topn=10)
# Out:
# [('Youtube', 0.7923596501350403),
#  ('youtube.com', 0.6960442066192627),
#  ('vid', 0.666364312171936),
#  ('YouTube', 0.6590824127197266),
#  ('vids', 0.620431125164032),
#  ('YouTube.com', 0.6139892339706421),
#  ('Youtube.com', 0.5950932502746582),
#  ('hulu', 0.5934920310974121),
#  ('www.youtube.com', 0.5922167897224426),
#  ('youtube_videos', 0.5909896492958069)]

# %%
wv.most_similar('india', restrict_vocab=500000, topn=10)
# Out:
# [('indian', 0.6967039704322815),
#  ('usa', 0.6836211085319519),
#  ('pakistan', 0.681516706943512),
#  ('chennai', 0.6675503253936768),
#  ('america', 0.6589399576187134),
#  ('sri_lanka', 0.64982008934021),
#  ('canada', 0.6490967869758606),
#  ('australia', 0.6368584036827087),
#  ('mexico', 0.6239137649536133),
#  ('uk', 0.6221641898155212)]

# %%
wv.most_similar('human',  topn=10)
# Out:
# [('human_beings', 0.6139679551124573),
#  ('humans', 0.5917960405349731),
#  ('impertinent_flamboyant_endearingly', 0.5868303179740906),
#  ('employee_Laura_Althouse', 0.5639359354972839),
#  ('humankind', 0.5636306405067444),
#  ('Human', 0.5524994134902954),
#  ('mankind', 0.5346406102180481),
#  ('Christine_Gaugler_head', 0.5272535681724548),
#  ('humanity', 0.5262271165847778),
#  ('sentient_intelligent', 0.5201493501663208)]

# %%
wv.most_similar('king',  topn=10)
# Out:
# [('kings', 0.7138045430183411),
#  ('queen', 0.6510956883430481),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204220056533813),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864824056625366),
#  ('ruler', 0.5797567367553711),
#  ('princes', 0.5646552443504333),
#  ('Prince_Paras', 0.5432944297790527),
#  ('throne', 0.5422105193138123)]

# %%
wv.similarity('hockey' , 'cricket')
# Out:
# 0.45641363

# %%
wv.similarity('football' , 'cricket')
# Out:
# 0.45974636

# %%
vec= wv['king'] - wv['man'] + wv['women']

# %%
vec
# Out:
# array([-0.33984375,  0.06298828, -0.00994873,  0.3305664 ,  0.10327148,
#        -0.25854492,  0.19677734, -0.32476807, -0.15917969,  0.45752716,
#        -0.39208984, -0.22460938,  0.02929688,  0.31982422, -0.0958252 ,
#        -0.05932617,  0.01855469, -0.03945923,  0.01101685,  0.33984375,
#         0.10351562,  0.14396667, -0.07641602,  0.06640625, -0.10839844,
#        -0.1953125 , -0.3564453 , -0.02124023, -0.16503906, -0.16247559,
#        -0.05519104, -0.1003418 ,  0.01464844,  0.23449707, -0.26611328,
#        -0.07080078, -0.26904297, -0.00292969, -0.06738281, -0.02050781,
#         0.04418945, -0.09326172,  0.12304688,  0.10626221,  0.10290527,
#         0.01660156, -0.10791016, -0.0065918 ,  0.17578125,  0.10028076,
#         0.22363281, -0.05761719, -0.31743622,  0.3922119 , -0.35498047,
#        -0.23643494, -0.01074219, -0.01334572, -0.15283203, -0.00793457,
#         0.08203125,  0.09985352,  0.003479  ,  0.11608887,  0.14550781,
# ...

# %%
wv.most_similar([vec])
# Out:
# [('king', 0.6478992700576782),
#  ('queen', 0.535493791103363),
#  ('women', 0.5233659148216248),
#  ('kings', 0.5162314772605896),
#  ('queens', 0.4995364248752594),
#  ('kumaris', 0.49238473176956177),
#  ('princes', 0.46233269572257996),
#  ('monarch', 0.45280295610427856),
#  ('monarchy', 0.4293173849582672),
#  ('kings_princes', 0.42342400550842285)]
